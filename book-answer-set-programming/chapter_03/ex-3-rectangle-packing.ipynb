# %% [markdown]
# # Packing rectangles in a rectangle
#
# You have a $5\times8$ grid and the following rectangles to pack into grid:
# - A $4\times4$
# - B $3\times3$
# - C and D $2\times2$
# - E $1\times1$
#
# One solution looks like this (the blanks are empty cells)
#
# AAAABBB_\
# AAAABBB_\
# AAAABBBE\
# AAAACCDD\
# ______CCDD
#
# How many solutions are there?

# %%
# %%file ./instances/rectangle.lp
#
# #const lx=8.
# #const ly=5.
#
# grid(1..lx, 1..ly).
# size(
#     a,4;
#     b,3;
#     c,2;
#     d,2;
#     e,1
# ).
#
# % bottom left corner
# {corner(X,Y,L): grid(X,Y)} = 1 :- size(L,_).
#
# % rectangles have to fit into the grid
# Y+S-1 <= ly :- corner(_,Y,L), size(L,S).
# X+S-1 <= lx :- corner(X,_,L), size(L,S).
#
# % no overlap
# filled(X + (1..S), Y + (1..S),L) :- corner(X,Y,L), size(L,S).
# L1 = L2 :- filled(X,Y,L1), filled(X,Y,L2).
#
# #show corner/3.
# Out:
# Overwriting ./instances/rectangle.lp

# %% [markdown]
# There are 224 possibilities to fill that grid with the rectangles:

# %%
# !clingo ./instances/rectangle.lp 0
# Out:
# clingo version 5.6.2
# Reading from ./instances/rectangle.lp
# Solving...
# Answer: 1
# corner(1,2,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(1,1,e)
# Answer: 2
# corner(1,2,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(2,1,e)
# Answer: 3
# corner(1,2,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(3,1,e)
# Answer: 4
# corner(1,2,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(4,1,e)
# Answer: 5
# corner(1,2,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(5,3,e)
# Answer: 6
# corner(1,2,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(5,4,e)
# Answer: 7
# corner(1,2,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(5,5,e)
# Answer: 8
# corner(1,2,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(1,1,e)
# Answer: 9
# corner(1,2,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(2,1,e)
# Answer: 10
# corner(1,2,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(3,1,e)
# Answer: 11
# corner(1,2,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(4,1,e)
# Answer: 12
# corner(1,2,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(5,3,e)
# Answer: 13
# corner(1,2,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(5,4,e)
# Answer: 14
# corner(1,2,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(5,5,e)
# Answer: 15
# corner(1,2,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(1,1,e)
# Answer: 16
# corner(1,2,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(2,1,e)
# Answer: 17
# corner(1,2,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(3,1,e)
# Answer: 18
# corner(1,2,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(4,1,e)
# Answer: 19
# corner(1,2,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(5,1,e)
# Answer: 20
# corner(1,2,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(5,2,e)
# Answer: 21
# corner(1,2,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(5,3,e)
# Answer: 22
# corner(1,2,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(1,1,e)
# Answer: 23
# corner(1,2,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(2,1,e)
# Answer: 24
# corner(1,2,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(3,1,e)
# Answer: 25
# corner(1,2,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(4,1,e)
# Answer: 26
# corner(1,2,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(5,1,e)
# Answer: 27
# corner(1,2,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(5,2,e)
# Answer: 28
# corner(1,2,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(5,3,e)
# Answer: 29
# corner(1,1,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(5,3,e)
# Answer: 30
# corner(1,1,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(5,4,e)
# Answer: 31
# corner(1,1,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(1,5,e)
# Answer: 32
# corner(1,1,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(2,5,e)
# Answer: 33
# corner(1,1,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(3,5,e)
# Answer: 34
# corner(1,1,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(4,5,e)
# Answer: 35
# corner(1,1,a) corner(6,3,b) corner(7,1,c) corner(5,1,d) corner(5,5,e)
# Answer: 36
# corner(1,1,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(5,3,e)
# Answer: 37
# corner(1,1,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(5,4,e)
# Answer: 38
# corner(1,1,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(1,5,e)
# Answer: 39
# corner(1,1,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(2,5,e)
# Answer: 40
# corner(1,1,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(3,5,e)
# Answer: 41
# corner(1,1,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(4,5,e)
# Answer: 42
# corner(1,1,a) corner(6,3,b) corner(5,1,c) corner(7,1,d) corner(5,5,e)
# Answer: 43
# corner(1,1,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(5,3,e)
# Answer: 44
# corner(1,1,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(5,1,e)
# Answer: 45
# corner(1,1,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(5,2,e)
# Answer: 46
# corner(1,1,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(1,5,e)
# Answer: 47
# corner(1,1,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(2,5,e)
# Answer: 48
# corner(1,1,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(3,5,e)
# Answer: 49
# corner(1,1,a) corner(6,1,b) corner(7,4,c) corner(5,4,d) corner(4,5,e)
# Answer: 50
# corner(1,1,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(5,3,e)
# Answer: 51
# corner(1,1,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(5,1,e)
# Answer: 52
# corner(1,1,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(5,2,e)
# Answer: 53
# corner(1,1,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(1,5,e)
# Answer: 54
# corner(1,1,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(2,5,e)
# Answer: 55
# corner(1,1,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(3,5,e)
# Answer: 56
# corner(1,1,a) corner(6,1,b) corner(5,4,c) corner(7,4,d) corner(4,5,e)
# Answer: 57
# corner(1,2,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(8,3,e)
# Answer: 58
# corner(1,2,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(3,1,e)
# Answer: 59
# corner(1,2,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(4,1,e)
# Answer: 60
# corner(1,2,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(8,1,e)
# Answer: 61
# corner(1,2,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(8,2,e)
# Answer: 62
# corner(1,2,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(2,1,e)
# Answer: 63
# corner(1,2,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(1,1,e)
# Answer: 64
# corner(1,2,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(8,3,e)
# Answer: 65
# corner(1,2,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(2,1,e)
# Answer: 66
# corner(1,2,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(3,1,e)
# Answer: 67
# corner(1,2,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(4,1,e)
# Answer: 68
# corner(1,2,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(1,1,e)
# Answer: 69
# corner(1,2,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(8,4,e)
# Answer: 70
# corner(1,2,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(8,5,e)
# Answer: 71
# corner(1,2,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(8,3,e)
# Answer: 72
# corner(1,2,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(4,1,e)
# Answer: 73
# corner(1,2,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(2,1,e)
# Answer: 74
# corner(1,2,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(3,1,e)
# Answer: 75
# corner(1,2,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(8,2,e)
# Answer: 76
# corner(1,2,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(8,1,e)
# Answer: 77
# corner(1,2,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(1,1,e)
# Answer: 78
# corner(1,2,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(8,3,e)
# Answer: 79
# corner(1,2,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(4,1,e)
# Answer: 80
# corner(1,2,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(2,1,e)
# Answer: 81
# corner(1,2,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(3,1,e)
# Answer: 82
# corner(1,2,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(1,1,e)
# Answer: 83
# corner(1,2,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(8,4,e)
# Answer: 84
# corner(1,2,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(8,5,e)
# Answer: 85
# corner(1,1,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(8,3,e)
# Answer: 86
# corner(1,1,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(8,1,e)
# Answer: 87
# corner(1,1,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(8,2,e)
# Answer: 88
# corner(1,1,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(1,5,e)
# Answer: 89
# corner(1,1,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(2,5,e)
# Answer: 90
# corner(1,1,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(3,5,e)
# Answer: 91
# corner(1,1,a) corner(5,1,b) corner(7,4,c) corner(5,4,d) corner(4,5,e)
# Answer: 92
# corner(1,1,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(8,1,e)
# Answer: 93
# corner(1,1,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(8,2,e)
# Answer: 94
# corner(1,1,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(8,3,e)
# Answer: 95
# corner(1,1,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(1,5,e)
# Answer: 96
# corner(1,1,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(2,5,e)
# Answer: 97
# corner(1,1,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(3,5,e)
# Answer: 98
# corner(1,1,a) corner(5,1,b) corner(5,4,c) corner(7,4,d) corner(4,5,e)
# Answer: 99
# corner(1,1,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(8,3,e)
# Answer: 100
# corner(1,1,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(8,4,e)
# Answer: 101
# corner(1,1,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(1,5,e)
# Answer: 102
# corner(1,1,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(2,5,e)
# Answer: 103
# corner(1,1,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(3,5,e)
# Answer: 104
# corner(1,1,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(4,5,e)
# Answer: 105
# corner(1,1,a) corner(5,3,b) corner(7,1,c) corner(5,1,d) corner(8,5,e)
# Answer: 106
# corner(1,1,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(8,3,e)
# Answer: 107
# corner(1,1,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(8,4,e)
# Answer: 108
# corner(1,1,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(1,5,e)
# Answer: 109
# corner(1,1,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(2,5,e)
# Answer: 110
# corner(1,1,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(3,5,e)
# Answer: 111
# corner(1,1,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(4,5,e)
# Answer: 112
# corner(1,1,a) corner(5,3,b) corner(5,1,c) corner(7,1,d) corner(8,5,e)
# Answer: 113
# corner(5,1,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(1,3,e)
# Answer: 114
# corner(5,1,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(1,2,e)
# Answer: 115
# corner(5,1,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(1,1,e)
# Answer: 116
# corner(5,1,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(6,5,e)
# Answer: 117
# corner(5,1,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(8,5,e)
# Answer: 118
# corner(5,1,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(7,5,e)
# Answer: 119
# corner(5,1,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(5,5,e)
# Answer: 120
# corner(5,1,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(4,2,e)
# Answer: 121
# corner(5,1,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(4,3,e)
# Answer: 122
# corner(5,1,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(4,1,e)
# Answer: 123
# corner(5,1,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(6,5,e)
# Answer: 124
# corner(5,1,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(8,5,e)
# Answer: 125
# corner(5,1,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(7,5,e)
# Answer: 126
# corner(5,1,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(5,5,e)
# Answer: 127
# corner(5,2,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(1,3,e)
# Answer: 128
# corner(5,2,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(1,2,e)
# Answer: 129
# corner(5,2,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(8,1,e)
# Answer: 130
# corner(5,2,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(5,1,e)
# Answer: 131
# corner(5,2,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(6,1,e)
# Answer: 132
# corner(5,2,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(7,1,e)
# Answer: 133
# corner(5,2,a) corner(2,1,b) corner(3,4,c) corner(1,4,d) corner(1,1,e)
# Answer: 134
# corner(5,2,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(7,1,e)
# Answer: 135
# corner(5,2,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(4,2,e)
# Answer: 136
# corner(5,2,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(4,3,e)
# Answer: 137
# corner(5,2,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(8,1,e)
# Answer: 138
# corner(5,2,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(5,1,e)
# Answer: 139
# corner(5,2,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(6,1,e)
# Answer: 140
# corner(5,2,a) corner(1,1,b) corner(3,4,c) corner(1,4,d) corner(4,1,e)
# Answer: 141
# corner(5,2,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(6,1,e)
# Answer: 142
# corner(5,2,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(1,3,e)
# Answer: 143
# corner(5,2,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(1,2,e)
# Answer: 144
# corner(5,2,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(7,1,e)
# Answer: 145
# corner(5,2,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(8,1,e)
# Answer: 146
# corner(5,2,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(5,1,e)
# Answer: 147
# corner(5,2,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(1,1,e)
# Answer: 148
# corner(5,1,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(1,2,e)
# Answer: 149
# corner(5,1,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(1,3,e)
# Answer: 150
# corner(5,1,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(1,1,e)
# Answer: 151
# corner(5,1,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(6,5,e)
# Answer: 152
# corner(5,1,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(7,5,e)
# Answer: 153
# corner(5,1,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(8,5,e)
# Answer: 154
# corner(5,1,a) corner(2,1,b) corner(1,4,c) corner(3,4,d) corner(5,5,e)
# Answer: 155
# corner(5,2,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(4,3,e)
# Answer: 156
# corner(5,2,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(8,1,e)
# Answer: 157
# corner(5,2,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(6,1,e)
# Answer: 158
# corner(5,2,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(7,1,e)
# Answer: 159
# corner(5,2,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(5,1,e)
# Answer: 160
# corner(5,2,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(4,4,e)
# Answer: 161
# corner(5,2,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(4,5,e)
# Answer: 162
# corner(5,2,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(4,3,e)
# Answer: 163
# corner(5,2,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(8,1,e)
# Answer: 164
# corner(5,2,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(6,1,e)
# Answer: 165
# corner(5,2,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(7,1,e)
# Answer: 166
# corner(5,2,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(5,1,e)
# Answer: 167
# corner(5,2,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(4,4,e)
# Answer: 168
# corner(5,2,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(4,5,e)
# Answer: 169
# corner(5,2,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(6,1,e)
# Answer: 170
# corner(5,2,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(1,3,e)
# Answer: 171
# corner(5,2,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(5,1,e)
# Answer: 172
# corner(5,2,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(7,1,e)
# Answer: 173
# corner(5,2,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(8,1,e)
# Answer: 174
# corner(5,2,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(1,4,e)
# Answer: 175
# corner(5,2,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(1,5,e)
# Answer: 176
# corner(5,2,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(7,1,e)
# Answer: 177
# corner(5,2,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(8,1,e)
# Answer: 178
# corner(5,2,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(6,1,e)
# Answer: 179
# corner(5,2,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(1,3,e)
# Answer: 180
# corner(5,2,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(5,1,e)
# Answer: 181
# corner(5,2,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(1,4,e)
# Answer: 182
# corner(5,2,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(1,5,e)
# Answer: 183
# corner(5,2,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(4,3,e)
# Answer: 184
# corner(5,2,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(4,1,e)
# Answer: 185
# corner(5,2,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(4,2,e)
# Answer: 186
# corner(5,2,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(5,1,e)
# Answer: 187
# corner(5,2,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(7,1,e)
# Answer: 188
# corner(5,2,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(8,1,e)
# Answer: 189
# corner(5,2,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(6,1,e)
# Answer: 190
# corner(5,1,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(4,3,e)
# Answer: 191
# corner(5,1,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(4,4,e)
# Answer: 192
# corner(5,1,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(4,5,e)
# Answer: 193
# corner(5,1,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(8,5,e)
# Answer: 194
# corner(5,1,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(7,5,e)
# Answer: 195
# corner(5,1,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(6,5,e)
# Answer: 196
# corner(5,1,a) corner(1,3,b) corner(3,1,c) corner(1,1,d) corner(5,5,e)
# Answer: 197
# corner(5,1,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(4,3,e)
# Answer: 198
# corner(5,1,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(4,4,e)
# Answer: 199
# corner(5,1,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(4,5,e)
# Answer: 200
# corner(5,1,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(6,5,e)
# Answer: 201
# corner(5,1,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(7,5,e)
# Answer: 202
# corner(5,1,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(8,5,e)
# Answer: 203
# corner(5,1,a) corner(1,3,b) corner(1,1,c) corner(3,1,d) corner(5,5,e)
# Answer: 204
# corner(5,1,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(1,3,e)
# Answer: 205
# corner(5,1,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(1,4,e)
# Answer: 206
# corner(5,1,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(1,5,e)
# Answer: 207
# corner(5,1,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(6,5,e)
# Answer: 208
# corner(5,1,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(8,5,e)
# Answer: 209
# corner(5,1,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(7,5,e)
# Answer: 210
# corner(5,1,a) corner(2,3,b) corner(3,1,c) corner(1,1,d) corner(5,5,e)
# Answer: 211
# corner(5,1,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(1,3,e)
# Answer: 212
# corner(5,1,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(1,4,e)
# Answer: 213
# corner(5,1,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(1,5,e)
# Answer: 214
# corner(5,1,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(6,5,e)
# Answer: 215
# corner(5,1,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(8,5,e)
# Answer: 216
# corner(5,1,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(7,5,e)
# Answer: 217
# corner(5,1,a) corner(2,3,b) corner(1,1,c) corner(3,1,d) corner(5,5,e)
# Answer: 218
# corner(5,1,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(4,2,e)
# Answer: 219
# corner(5,1,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(4,3,e)
# Answer: 220
# corner(5,1,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(4,1,e)
# Answer: 221
# corner(5,1,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(6,5,e)
# Answer: 222
# corner(5,1,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(8,5,e)
# Answer: 223
# corner(5,1,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(7,5,e)
# Answer: 224
# corner(5,1,a) corner(1,1,b) corner(1,4,c) corner(3,4,d) corner(5,5,e)
# SATISFIABLE
#
# Models       : 224
# Calls        : 1
# Time         : 0.007s (Solving: 0.00s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.007s
